# %% [markdown]
# # **1. Importing and installing Libraries**

# %% [markdown]
# ### 1.1. Installing Libraries

# %%
# !pip install -q datascience
# !pip install -q pandas-profiling
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.6/357.6 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 17.7 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %% [markdown]
# ### 1.2. Upgrading Libraries

# %%
# !pip install -q --upgrade datascience
# !pip install -q --upgrade yellowbrick

# %% [markdown]
# ### 1.3. Importing Libraries

# %%
import numpy as np
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_colwidth',None)
pd.set_option('display.max_rows',None)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('mode.chained_assignment',None)
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ---
# # **Data Acquisition and Description**
# ---
# - The Department of Natural Resources Canada is the department of the Federal Government of Canada responsible for the management of natural resources, energy, minerals and metals, forests, earth sciences, and the environment.
# - Canada's total GHG emissions in 2019 were 730 megatonnes of carbon dioxide equivalent (Mt CO2 eq), a slight increase from 728 Mt CO2 eq in 2018.
# - The major proportion of this data was emissions from personal vehicles.
#
# | Records | Features | Size |
# | :-- | :-- | :-- |
# | 5760 | 12 | 540 KB|
#
# |Column Name | Description |
# | :--| :--|
# | Make |	Company of the vehicle|
# |Model|	Car Model|
# | Vehicle Class| 	Class of vehicle depending on their utility, capacity and weight|
# |Engine Size(L)| 	Size of engine used in Litre |
# |Cylinders | No. of cylinder system used in the vehicle |
# |Transmission|	Transmission type with number of gears|
# |Fuel Type|	Type of Fuel used|
# |Fuel Consumption City (L/100 km)|	Fuel consumption in city roads (L/100 km)|
# |Fuel Consumption Hwy (L/100 km)|	Fuel consumption in highways (L/100 km)|
# |Fuel Consumption Comb (L/100 km)|	The combined fuel consumption (55% city, 45% highway) is shown in L/100 km|
# |Fuel Consumption Comb (mpg)|	The combined fuel consumption in both city and highway is shown in mile per gallon(mpg)|
# |CO2 Emissions(g/km)|	The tailpipe emissions of carbon dioxide (in grams per kilometre) for combined city and highway driving|

# %%
df_train = pd.read_csv('/content/train_data.csv')

# %% [markdown]
# ### 2.1 Data Information

# %%
df_train.head(10)
# Out:
#             Make                   Model Vehicle Class  Engine Size(L)  \
# 0      CHEVROLET                TRAX 4WD   SUV - SMALL         1.40000
# 1           FORD                 MUSTANG    SUBCOMPACT         5.80000
# 2  MERCEDES-BENZ            E 400 4MATIC      MID-SIZE         3.00000
# 3         JAGUAR                     XFR      MID-SIZE         5.00000
# 4          DODGE  CHALLENGER SRT HELLCAT      MID-SIZE         6.20000
# 5            BMW    M4 Coupe Competition       COMPACT         3.00000
# 6        GENESIS                 G80 AWD     FULL-SIZE         3.30000
# 7            BMW            Z4 sDRIVE35i    TWO-SEATER         3.00000
# 8  MERCEDES-BENZ        S 550 4MATIC LWB     FULL-SIZE         4.70000
# 9            KIA                   FORTE      MID-SIZE         2.00000
#
#    Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          4          AS6         X                           9.90000
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5760 entries, 0 to 5759
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              5760 non-null   object
#  1   Model                             5760 non-null   object
#  2   Vehicle Class                     5760 non-null   object
#  3   Engine Size(L)                    5760 non-null   float64
#  4   Cylinders                         5760 non-null   int64
#  5   Transmission                      5760 non-null   object
#  6   Fuel Type                         5760 non-null   object
#  7   Fuel Consumption City (L/100 km)  5760 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   5760 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  5760 non-null   float64
#  10  Fuel Consumption Comb (mpg)       5760 non-null   int64
# ...

# %% [markdown]
# ---
# ### Observations
# ---
# - There is **7 Numeric** and **5 Categorical** variables.
# - There is **No Null** values spotted in the data set.

# %% [markdown]
# ### 2.2. Data Description

# %%
df_train.describe()
# Out:
#        Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# count      5760.00000 5760.00000                        5760.00000
# mean          3.16958    5.62969                          12.58030
# std           1.36119    1.84045                           3.51150
# min           0.90000    3.00000                           4.20000
# 25%           2.00000    4.00000                          10.10000
# 50%           3.00000    6.00000                          12.10000
# 75%           3.70000    6.00000                          14.60000
# max           8.40000   16.00000                          30.60000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                       5760.00000                        5760.00000
# mean                           9.05283                          10.99318
# std                            2.22131                           2.89714
# ...

# %% [markdown]
# ### 2.3. Unique data

# %%
df_train.nunique()
# Out:
# Make                                  42
# Model                               1906
# Vehicle Class                         16
# Engine Size(L)                        51
# Cylinders                              8
# Transmission                          27
# Fuel Type                              4
# Fuel Consumption City (L/100 km)     207
# Fuel Consumption Hwy (L/100 km)      141
# Fuel Consumption Comb (L/100 km)     179
# Fuel Consumption Comb (mpg)           54
# CO2 Emissions(g/km)                  324
# dtype: int64

# %% [markdown]
# ### Observations:
# - Data looks clean as of now after looking every feature's unique value.

# %%
df_test = pd.read_csv('/content/test_data.csv')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1625 entries, 0 to 1624
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              1625 non-null   object
#  1   Model                             1625 non-null   object
#  2   Vehicle Class                     1625 non-null   object
#  3   Engine Size(L)                    1625 non-null   float64
#  4   Cylinders                         1625 non-null   int64
#  5   Transmission                      1625 non-null   object
#  6   Fuel Type                         1625 non-null   object
#  7   Fuel Consumption City (L/100 km)  1625 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   1625 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  1625 non-null   float64
#  10  Fuel Consumption Comb (mpg)       1625 non-null   int64
# dtypes: float64(4), int64(2), object(5)
# ...

# %% [markdown]
# # **Data Preprocessing:**

# %% [markdown]
# ### 3.1. Data Handling:
#
# - In this section we will identify missing values in the data.
# -  Ensure to take appropriate measures to handle missing values if any.

# %%
(df_train.shape[0] - df_train.count()).sort_values()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
df_train.shape[0] - df_train.count()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %% [markdown]
# #### observations
# - Above are the two ways of measuring missing values in dataset
# - As there is no missing value, data seems clean.

# %%
df_train.duplicated().sum()
# Out:
# 693

# %%
df_train['Cylinders'].unique()
# Out:
# array([ 4,  8,  6,  3, 12, 10,  5, 16])

# %% [markdown]
# ---
# # **Exploratory Data Analysis**
# ---
# Exploratory data analysis is generally cross-classified in two ways.
#
# - First, each method is either non-graphical or graphical.
#
# - And second, each method is either univariate or multivariate (usually just bivariate).
#
#
#
#
# 1.   **Univariate Analysis**
# -
# Univariate analysis is the simplest form of data analysis, where the data being analyzed consists of only one variable.
# Since it’s a single variable, it doesn’t deal with causes or relationships.The main purpose of the univariate analysis is to describe the data and find patterns that exist within it.
# Visualizations used for performing univariate analysis:
#      * Line chart
#      * Histogram
#
#
#
#
# 2.   **Multivariate analysis**
# - Multivariate data analysis refers to any statistical technique used to analyze data that arises from more than one variable.
#
# - This model’s more realistic applications, where each situation, product, or decision involves more than a single variable.
#
# - This model’s more realistic applications, where each situation, product, or decision involves more than a single variable.
#     * Scatter Plot
#     * Heat map

# %% [markdown]
# ### 4.1 Univariate Analysis
# - **Bar Graph:** It is used when there is one **categorical variable**
# - **Histogram:** It is used for **Continuous variable**
# -  **KDE Plot:** without Hue, it can be used for one **Continuous variable**

# %%
df_train.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %% [markdown]
# **KDE Plot:** Kernel Density Estimate(KDE)
# - Plot univariate or bivariate distributions using kernel density estimation.
# - A kernel density estimate (KDE) plot is a method for visualizing
# the distribution of observations in a dataset, analogous to a histogram.
# - KDE represents the data using a continuous probability density curve in one or more dimensions.

# %%
paper = plt.figure(figsize=[7,5])
sns.kdeplot(x='CO2 Emissions(g/km)',data =df_train)
plt.show()

# %% [markdown]
# ### Observations:
# - Mostly **170** to **320** grams per kilometer of CO2 is released from the tailpipe of vehicle in city and highway transmissions.

# %%
sns.histplot(data = df_train['CO2 Emissions(g/km)'],kde = True)
# Out:
# <Axes: xlabel='CO2 Emissions(g/km)', ylabel='Count'>

# %%
paper = plt.figure(figsize=[5,5])
sns.boxplot(data= df_train['Fuel Consumption Comb (L/100 km)'])
plt.show()

# %% [markdown]
# **Pearson Correlation Coefficient**

# %%
df_train.corr()
# Out:
#                                   Engine Size(L)  Cylinders  \
# Engine Size(L)                           1.00000    0.92729
# Cylinders                                0.92729    1.00000
# Fuel Consumption City (L/100 km)         0.83191    0.80223
# Fuel Consumption Hwy (L/100 km)          0.75910    0.71524
# Fuel Consumption Comb (L/100 km)         0.81666    0.78168
# Fuel Consumption Comb (mpg)             -0.75870   -0.72022
# CO2 Emissions(g/km)                      0.85142    0.83384
#
#                                   Fuel Consumption City (L/100 km)  \
# Engine Size(L)                                             0.83191
# Cylinders                                                  0.80223
# Fuel Consumption City (L/100 km)                           1.00000
# Fuel Consumption Hwy (L/100 km)                            0.94806
# Fuel Consumption Comb (L/100 km)                           0.99383
# Fuel Consumption Comb (mpg)                               -0.92651
# ...

# %% [markdown]
# ### **4.2 Bivariate Analysis:**
# - **Scatter Plot:** It is used when there is two **Continuous Variables**
# -  **Histogram:** It is used with **Hue** if there is **one continuous and once categorical variable** also if both is categorical.
# - **KDE Plot:** It is used with **Hue** if there is **one continuous and once categorical variable**

# %%
paper = plt.figure(figsize = [15,7])
plt.subplot(1,2,1)
sns.scatterplot(data = df_train, y =df_train['Engine Size(L)'], x = df_train['CO2 Emissions(g/km)'],hue = df_train['Fuel Consumption Comb (L/100 km)'], legend = 'auto', palette = 'Spectral')
plt.subplot(1,2,2)
sns.scatterplot(data = df_train, y =df_train['Fuel Consumption Comb (L/100 km)'], x = df_train['CO2 Emissions(g/km)'],hue = df_train['Engine Size(L)'], legend = 'auto')
plt.show()

# %% [markdown]
# ### **4.3 Multi-Variate Analysis**
# - Heatmap
# - Pair Plot

# %%
paper = plt.figure(figsize = [7,5])
sns.heatmap(df_train.corr(), annot= True)
plt.title('Heatmap: Correlation among various features', size = 14)
plt.show()

# %%
paper = plt.figure(figsize = [15,7])
sns.pairplot(df_train, hue="Engine Size(L)", diag_kind="hist")

# %%
df_train.head()
# Out:
#             Make                   Model Vehicle Class  Engine Size(L)  \
# 0      CHEVROLET                TRAX 4WD   SUV - SMALL         1.40000
# 1           FORD                 MUSTANG    SUBCOMPACT         5.80000
# 2  MERCEDES-BENZ            E 400 4MATIC      MID-SIZE         3.00000
# 3         JAGUAR                     XFR      MID-SIZE         5.00000
# 4          DODGE  CHALLENGER SRT HELLCAT      MID-SIZE         6.20000
#
#    Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          4          AS6         X                           9.90000
# 1          8           M6         Z                          15.90000
# 2          6           A9         Z                          11.80000
# 3          8          AS8         E                          21.30000
# 4          8           A8         Z                          18.00000
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# ...

# %% [markdown]
# ### Observations:
# - There is high correlation of
#   * 'Cylinders',
#   * 'Fuel Consumption City (L/100 km)',
#   * 'Fuel Consumption Hwy (L/100 km)',
#   *  'Fuel Consumption Comb (L/100 km)' with 'CO2 Emission (g/km)' and **negatively correlated** with
#   * 'Fuel Consumption Comb (mpg)'
# - Also there are few **categorical variables** which are not adding value for our target variables:
#  *  'Make',
#  * 'Model',
#  * 'Vehicle Class',
#  *  'Transmission',
#  * 'Fuel Type'
# - Above data need to be dropped to train our model.

# %%
df_train.skew()
# Out:
# Engine Size(L)                     0.80432
# Cylinders                          1.12364
# Fuel Consumption City (L/100 km)   0.82235
# Fuel Consumption Hwy (L/100 km)    1.08450
# Fuel Consumption Comb (L/100 km)   0.90318
# Fuel Consumption Comb (mpg)        0.97436
# CO2 Emissions(g/km)                0.53541
# dtype: float64

# %%
plt.figure(figsize = [15,7])
df_train.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Observations:
# - Few features are relatively highly skewed in contrast to the target variable.

# %%
plt.figure(figsize = [15,7])
plt.subplot(1,4,1)
df_train['CO2 Emissions(g/km)'].plot.box(legend = True)
plt.subplot(1,4,2)
df_train['Fuel Consumption City (L/100 km)'].plot.box(legend = True)
plt.subplot(1,4,3)
df_train['Fuel Consumption Hwy (L/100 km)'].plot.box(legend = True)
plt.subplot(1,4,4)
df_train['Fuel Consumption Comb (L/100 km)'].plot.box(legend = True)
# Out:
# <Axes: >

# %% [markdown]
# ### **4.4 Data Profiling**

# %% [markdown]
# ### Dropping redundant features as above mentioned.

# %%
df = df_train.drop(df_train[['Make', 'Model', 'Vehicle Class','Transmission', 'Fuel Type']], axis =1)
df.head()
# Out:
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0         1.40000          4                           9.90000
# 1         5.80000          8                          15.90000
# 2         3.00000          6                          11.80000
# 3         5.00000          8                          21.30000
# 4         6.20000          8                          18.00000
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                          7.80000                           8.90000
# 1                          9.90000                          13.20000
# 2                          8.70000                          10.40000
# 3                         14.10000                          18.10000
# 4                         10.70000                          14.70000
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           32                  210
# 1                           21                  304
# ...

# %% [markdown]
# # **Data Post-Processing**

# %% [markdown]
# ### **5.1 Data Preparation**
# - Feature Extraction: x_train icontains all the features other than target variable

# %%
x = df.iloc[:,0:6]
print(x.columns)
y = df['CO2 Emissions(g/km)']
print(y.head(10))
# Out:
# Index(['Engine Size(L)', 'Cylinders', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)'],
#       dtype='object')
# 0    210
# 1    304
# 2    246
# 3    290
# 4    338
# 5    273
# 6    282
# 7    282
# 8    280
# 9    195
# Name: CO2 Emissions(g/km), dtype: int64

# %% [markdown]
# # **Model Development and Evaluation**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### **6.1 Train Test and Split**

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4608, 6)
# (1152, 6)
# (4608,)
# (1152,)

# %% [markdown]
# ### **6.2 Linear Regression**

# %%
lr = LinearRegression()
lr.fit(X= x_train, y = y_train)
# Out:
# LinearRegression()

# %%
y_hat_train = lr.predict(x_train)
y_hat_test = lr.predict(x_test)

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [ 4.93716379  7.33673384  1.60323154  4.92608226 -0.38086664 -3.40300204]
# 226.93417019365364

# %%
def model_eval(actual,predicted):
  rmse = np.sqrt(mean_squared_error(actual,predicted))
  R2= r2_score(actual,predicted)
  print("The RMSE for the model is: ", round(rmse,2))
  print("The R2 Score for the models is: ", round(R2,3))

# %%
model_eval(y_train, y_hat_train)
# Out:
# The RMSE for the model is:  17.85
# The R2 Score for the models is:  0.908

# %%
y_pred = lr.predict(dftest)
y_pred
# Out:
# array([257.35137676, 321.97424319, 324.81564832, ..., 283.94630743,
#        198.97003789, 294.31194312])

# %%
# Out:
# array([257.35137676, 321.97424319, 324.81564832, ..., 283.94630743,
#        198.97003789, 294.31194312])

# %%
df_test.head()
# Out:
#         Make                 Model            Vehicle Class  Engine Size(L)  \
# 0    PORSCHE  Panamera 4 Executive                FULL-SIZE         3.00000
# 1        BMW          M6 CABRIOLET               SUBCOMPACT         4.40000
# 2        GMC                SIERRA  PICKUP TRUCK - STANDARD         6.20000
# 3  CHEVROLET             SILVERADO  PICKUP TRUCK - STANDARD         5.30000
# 4     TOYOTA           4Runner 4WD           SUV - STANDARD         4.00000
#
#    Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          6          AM8         Z                          12.40000
# 1          8          AM7         Z                          17.30000
# 2          8           A8         Z                          16.10000
# 3          8           A6         X                          14.60000
# 4          6          AS5         X                          14.30000
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# ...

# %%
index = np.arange(1,1626)

# %%
index_= pd.DataFrame(index)
index_.head()
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
y_pred = pd.DataFrame(y_pred)
y_pred.head()
# Out:
#           0
# 0 257.35138
# 1 321.97424
# 2 324.81565
# 3 306.23779
# 4 295.75934

# %%
sub_df_ = index_.join(y_pred, lsuffix='Index_col', rsuffix='Pred_CO2_Emission')
print(sub_df_.head(10))
# Out:
#    0Index_col  0Pred_CO2_Emission
# 0           1           257.35138
# 1           2           321.97424
# 2           3           324.81565
# 3           4           306.23779
# 4           5           295.75934
# 5           6           325.24848
# 6           7           250.87415
# 7           8           216.11297
# 8           9           236.49987
# 9          10           224.27197

# %%
sub_df = pd.DataFrame(sub_df_)
sub_df.head(10)
sub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1625 entries, 0 to 1624
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   0Index_col          1625 non-null   int64
#  1   0Pred_CO2_Emission  1625 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 25.5 KB

# %%
sub_df.to_csv('submission.csv', index=False, header=False)

# %%
y_pred.head(10)
y_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1625 entries, 0 to 1624
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1625 non-null   float64
# dtypes: float64(1)
# memory usage: 12.8 KB

# %% [markdown]
# ### **6.3 Feature Scaling**
# - Using StandardScaler, sclae the features of the data.
# - Used for standardizing features by removing the mean and scaling to unit variance. **Standardization** is important in many machine learning algorithms that are sensitive to the scale of input features. The **StandardScaler** is part of the **sklearn.preprocessing module**.
# - StandardScaler is **sensitive to outliers**, and the features may scale differently from each other in the presence of outliers.
# - z =(x-u)/s
#  * u: mean
#  * s: standard deviation

# %%
from sklearn.preprocessing import StandardScaler

# %%
def scale_data(data=None):
  sc = StandardScaler()
  scaled_data = sc.fit_transform(data)
  scaled_dataframe = pd.DataFrame(data=scaled_data, columns=data.columns)
  return scaled_dataframe

# %%
scaled_data = scale_data(data=df)
scaled_data.head()
# Out:
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0        -1.30014   -0.88556                          -0.76336
# 1         1.93261    1.28801                           0.94546
# 2        -0.12460    0.20123                          -0.22223
# 3         1.34484    1.28801                           2.48340
# 4         2.22650    1.28801                           1.54355
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                         -0.56405                          -0.72256
# 1                          0.38142                           0.76179
# 2                         -0.15885                          -0.20476
# 3                          2.27236                           2.45326
# 4                          0.74160                           1.27959
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                      0.63296             -0.70014
# 1                     -0.89244              0.90425
# ...

# %%
x_ = scaled_data.iloc[:,0:6]
print(x.columns)
y_ = scaled_data['CO2 Emissions(g/km)']
print(y.head(10))
# Out:
# Index(['Engine Size(L)', 'Cylinders', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)'],
#       dtype='object')
# 0    210
# 1    304
# 2    246
# 3    290
# 4    338
# 5    273
# 6    282
# 7    282
# 8    280
# 9    195
# Name: CO2 Emissions(g/km), dtype: int64

# %%
x_train_sc, x_test_sc, y_train_sc, y_test_sc = train_test_split(x_, y_, test_size = 0.2)

# %%
print(x_train_sc.shape)
print(x_test_sc.shape)
print(y_train_sc.shape)
print(y_test_sc.shape)
# Out:
# (4608, 6)
# (1152, 6)
# (4608,)
# (1152,)

# %%
lr = LinearRegression()
lr.fit(X= x_train_sc, y = y_train_sc)
# Out:
# LinearRegression()

# %%
y_hat_train_sc = lr.predict(x_train)
y_hat_test_sc = lr.predict(x_test)

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [ 0.11785277  0.23916981  0.1952379   0.28139018 -0.21747532 -0.41908151]
# 5.184122058765096e-05

# %%
def model_eval(actual,predicted):
  rmse = np.sqrt(mean_squared_error(actual,predicted))
  R2= r2_score(actual,predicted)
  print("The RMSE for the model is: ", round(rmse,2))
  print("The R2 Score for the models is: ", round(R2,2))

# %%
model_eval(y_train_sc, y_hat_train_sc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-9c859fc4e561> in <cell line: 1>()
# ----> 1 model_eval(y_train_sc, y_hat_train_sc)
#
# <ipython-input-54-e686a5810453> in model_eval(actual, predicted)
#       1 def model_eval(actual,predicted):
# ----> 2   rmse = np.sqrt(mean_squared_error(actual,predicted))
#       3   R2= r2_score(actual,predicted)
#       4   print("The RMSE for the model is: ", round(rmse,2))
#       5   print("The R2 Score for the models is: ", round(R2,2))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#
# ...

# %% [markdown]
# ### Using training and test data separately

# %%
x = df.iloc[:,0:6]
print(x.columns)
y = df['CO2 Emissions(g/km)']
print(y.head(10))
# Out:
# Index(['Engine Size(L)', 'Cylinders', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)'],
#       dtype='object')
# 0    210
# 1    304
# 2    246
# 3    290
# 4    338
# 5    273
# 6    282
# 7    282
# 8    280
# 9    195
# Name: CO2 Emissions(g/km), dtype: int64

# %%
x_train = x
y_train = y
print(x_train.shape)
print(y_train.shape)
# Out:
# (5760, 6)
# (5760,)

# %%
dftest = df_test.drop(df_test[['Make', 'Model', 'Vehicle Class','Transmission', 'Fuel Type']], axis =1)
dftest.head()
# Out:
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0         3.00000          6                          12.40000
# 1         4.40000          8                          17.30000
# 2         6.20000          8                          16.10000
# 3         5.30000          8                          14.60000
# 4         4.00000          6                          14.30000
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                          9.00000                          10.90000
# 1                         11.60000                          14.70000
# 2                         11.40000                          14.00000
# 3                         10.30000                          12.70000
# 4                         11.90000                          13.20000
#
#    Fuel Consumption Comb (mpg)
# 0                           26
# 1                           19
# 2                           20
# 3                           22
# ...

# %%
df_test.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)'],
#       dtype='object')

# %%
dftest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1625 entries, 0 to 1624
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Engine Size(L)                    1625 non-null   float64
#  1   Cylinders                         1625 non-null   int64
#  2   Fuel Consumption City (L/100 km)  1625 non-null   float64
#  3   Fuel Consumption Hwy (L/100 km)   1625 non-null   float64
#  4   Fuel Consumption Comb (L/100 km)  1625 non-null   float64
#  5   Fuel Consumption Comb (mpg)       1625 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 76.3 KB
